# %% [markdown]
# # Plotting Charts with Seaborn (Simple Charts)
#
# **There are various kinds of charts that can be plotted from a given data, that helps us to understand data more clearly. Most of these charts can be plotted using Seaborn.**
#
#
# **All charts have different properties and tells different characteristics about the data. Some types of the charts provided with Seaborn are:**
# - Line plots
# - Scatter plots
# - Heatmaps
# - Histograms
# - Box plots
# - Violin plots
# - Bar charts
# - Pie charts, etc
#
#
# We will discuss most of the charts in details here.

# %% [markdown]
# ## Line-charts
#
# A line plot is a type of plot in which data points are represented as a **series of connected line segments**. In Machine Learning and EDA, line plots are often used to **visualize the trends and patterns in a dataset over time or across different values** of an independent variable.
#
#
# ### Uses of Line charts in Machine Learning and EDA:
#
# - **Visualizing time series data**: Line plots are useful for visualizing time series data, where the data points are collected at regular intervals over time. By plotting the data points in order of time, a line plot can **reveal patterns and trends** that might not be apparent from a simple tabular representation of the data. For example, in **stock price analysis**, line plots can be used to visualize the trend of stock prices over time.
#
#
# - **Exploring the relationship between two variables**: Line plots can also be used to explore the relationship between two variables. For example, in Machine Learning, we may be interested in **visualizing the relationship between a feature and the target variable**. By plotting the feature variable on the x-axis and the target variable on the y-axis, we can see if there is a **linear relationship between the two variables**.
#
#
# - **Visualizing model performance**: Line plots can be used to *visualize the performance of Machine Learning models over time or across different hyperparameter settings*. By plotting the model **performance metric (such as accuracy or F1 score)** on the y-axis and the hyperparameter values on the x-axis, we can see how the model performs as the hyperparameters are tuned.
#
#
# - **Identifying outliers**: Outliers are data points that fall far outside the expected range of values for a given variable. *By plotting the data on a line plot, outliers can be easily identified as points that **deviate significantly** from the overall trend of the data*.
#
#
# Overall, line plots are a powerful tool for visualizing trends and patterns in data, and can be used in a variety of applications in Machine Learning and EDA.

# %%
### Importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_theme(style='darkgrid')

# %matplotlib inline

# %%
### Loading the data

df = pd.read_csv('../data/fifa.csv', parse_dates=True, index_col='Date')
df
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %%
### Plotting the line plot
# METHOD-1

df.plot(figsize=(18, 8))
plt.xlabel('Time Period', weight='bold')
plt.ylabel('Ranking', weight='bold')
plt.title("FIFA Rankings of different countries over time")
plt.show()

# %%
# METHOD-2

plt.figure(figsize=(18, 8))
sns.lineplot(data=df)
plt.xlabel('Time Period', weight='bold', size=16)
plt.ylabel('Ranking', weight='bold', size=16)
plt.title("FIFA Rankings of different countries over time", weight='bold', size=18)
plt.show()

# %% [markdown]
# ### Plotting the subsets of the data

# %%
# METHOD-1

plt.figure(figsize=(16, 8))
sns.lineplot(data=df[['ARG', 'BRA', 'ESP']])
plt.xlabel('Time Period', weight='bold', size=16)
plt.ylabel('Ranking', weight='bold', size=16)
plt.title("FIFA Rankings of different countries over time", weight='bold', size=18)
plt.show()

# %%
# METHOD-2

plt.figure(figsize=(16, 8))
sns.lineplot(data=df['ARG'], label='Argentina')
sns.lineplot(data=df['BRA'], label='Brazil')
sns.lineplot(data=df['ESP'], label='Spain')
plt.xlabel('Time Period', weight='bold', size=16)
plt.ylabel('Ranking', weight='bold', size=16)
plt.title("FIFA Rankings of different countries over time", weight='bold', size=18)
plt.show()

# %%
# METHOD-3

df[['ARG', 'BRA', 'ESP']].plot(figsize=(16, 8))
plt.xlabel('Time Period', weight='bold', size=16)
plt.ylabel('Ranking', weight='bold', size=16)
plt.title("FIFA Rankings of different countries over time", weight='bold', size=18)
plt.show()

# %% [markdown]
# ## Line plot with respect to time

# %%
### Incorporating the datetime variables
# Using .dt for pandas datetime variables and extracting year, month, week and other datetime variables from those

df.reset_index(inplace=True)
df['Date'] = pd.to_datetime(df['Date'])

df['year'] = df.Date.dt.year
df['month'] = df.Date.dt.month
df['week'] = df.Date.dt.weekofyear
df['day'] = df.Date.dt.dayofyear
df['dom'] = df.Date.dt.day
df['dow'] = df.Date.dt.day_of_week

df
# Out:
#           Date   ARG  BRA   ESP   FRA  GER   ITA  year  month  week  day  dom  \
# 0   1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0  1993      8    31  220    8
# 1   1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0  1993      9    38  266   23
# 2   1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0  1993     10    42  295   22
# 3   1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0  1993     11    46  323   19
# 4   1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0  1993     12    51  357   23
# ..         ...   ...  ...   ...   ...  ...   ...   ...    ...   ...  ...  ...
# 281 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0  2018      2     7   46   15
# 282 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0  2018      3    11   74   15
# 283 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0  2018      4    15  102   12
# 284 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0  2018      5    20  137   17
# 285 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0  2018      6    23  158    7
#
#      dow
# 0      6
# 1      3
# ...

# %% [markdown]
# ### Yearly Analysis

# %%
### Getting the mean ranking for each year for each country
### Using **Groupby** function for the same, grouped by year and mean taken

yearly_mean_ranking = df.groupby(['year']).mean()[['ARG', 'BRA', 'ESP', 'FRA', 'GER', 'ITA']].astype('int')
yearly_mean_ranking
# Out:
#       ARG  BRA  ESP  FRA  GER  ITA
# year
# 1993    8    3    9   12    2    2
# 1994    8    1    5   16    2    6
# 1995    7    1    3   15    3    3
# 1996   15    1    7    4    2    5
# 1997   15    1    4    8    2    9
# 1998    6    1   16    7    2   10
# 1999    6    1    6    2    4    6
# 2000    4    1    4    2    7    9
# 2001    2    1    6    1    9    4
# 2002    3    1    5    1    7    8
# 2003    4    1    2    2    6   11
# 2004    5    1    3    2   11    9
# 2005    3    1    6    4   16   11
# 2006    4    1    7    4   12    7
# 2007    2    2    7    4    4    2
# 2008    3    3    2    9    3    2
# 2009    6    3    1    9    3    4
# 2010    6    2    1   15    4    9
# 2011    7    4    1   16    3    8
# 2012    7    9    1   15    2    8
# 2013    3   14    1   19    2    6
# 2014    3    6    4   12    1   10
# 2015    1    5    9   16    1   13
# 2016    1    5    7   14    3   13
# 2017    2    1    9    7    2   13
# ...

# %%
### Plotting the above data

yearly_mean_ranking.plot(figsize=(16, 8));

# %% [markdown]
# **Observations:**
# - France had improved their rankings around 2000 to 2006, then again rankings decreased
# - Brazil has very good rankings from starting till 2010, then decreased, again improving around end
# - Similarly, other countries can be observed..

# %% [markdown]
# ### Last 5 years

# %%
### Last 5 years average ranking data

yearly_mean_ranking.iloc[-5:]
# Out:
#       ARG  BRA  ESP  FRA  GER  ITA
# year
# 2014    3    6    4   12    1   10
# 2015    1    5    9   16    1   13
# 2016    1    5    7   14    3   13
# 2017    2    1    9    7    2   13
# 2018    4    2    7    8    1   16

# %%
### Plotting the above data

yearly_mean_ranking.iloc[-5:].plot(figsize=(16, 8));

# %% [markdown]
# **Last 5 years observations:**
# - Germany and Argentina performed consistently at top
# - Brazil improved rankings from around 6 to top in last 2 years
# - Spain has maintained its rankings around 4-9 for the whole time
# - France and Italy have the worst rankings for the whole time

# %% [markdown]
# ### Monthly analysis over years

# %%
### Mean ranking over months for all years

df.groupby(['month']).mean().iloc[:, :6].astype('int')
# Out:
#        ARG  BRA  ESP  FRA  GER  ITA
# month
# 1        4    3    4    8    5    8
# 2        5    3    5    8    5    8
# 3        4    3    5    8    5    8
# 4        5    2    5    9    5    9
# 5        5    2    5    9    5    9
# 6        5    3    4    8    4    8
# 7        5    2    5    9    4    7
# 8        5    3    5    9    4    7
# 9        5    2    6    9    4    7
# 10       5    2    5    8    4    8
# 11       5    3    5    8    4    8
# 12       5    3    5    8    5    8

# %%
df.groupby(['month']).mean().iloc[:, :6].astype('int').plot(figsize=(14, 6))
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# **On mean ranking analysis over months for all years following observations can be observed:**
# - Brazil shows the best ranking
# - France with the worst ranking, followed by Italy
# - Argentina, Spain and Germany lies in the mid

# %% [markdown]
# ### There can be similar analysis over different other datatime variables

# %% [markdown]
# ## Trying other dataset [flight data]
#
# **This data counts the number of passengers in a particular flight measured over time from 1949 to 1960**

# %%
df2 = sns.load_dataset('flights')
df2.head(2)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118

# %%
### Plotting wrt years, on each month

plt.figure(figsize=(14, 8))
sns.lineplot(x='year', y='passengers', hue='month', data=df2)
plt.xlabel('Year', weight='bold')
plt.ylabel('Passengers', weight='bold')
plt.title('Line plot for Passengers in flight measured on different month with years', weight='bold', size=20)
plt.show()

# %% [markdown]
# **Increasing trend for each month across all years**

# %%
### Plotting wrt months, on each year

plt.figure(figsize=(14, 8))
sns.lineplot(x='month', y='passengers', hue='year', data=df2)
plt.xlabel('Month', weight='bold')
plt.ylabel('Passengers', weight='bold')
plt.title('Line plot for Passengers in flight measured on different years with months', weight='bold', size=20)
plt.show()

# %% [markdown]
# **Similar pattern for all months throughout the year with increasing trend with passing years**

# %%
### Concept note for next cell

df2.set_index(['year', 'month']) # Set both year and month column as index which will be helpful in plotting passengers wrt both indexed
# Out:
#             passengers
# year month
# 1949 Jan           112
#      Feb           118
#      Mar           132
#      Apr           129
#      May           121
# ...                ...
# 1960 Aug           606
#      Sep           508
#      Oct           461
#      Nov           390
#      Dec           432
#
# [144 rows x 1 columns]

# %%
### Plotting passengers with reference to both year and month

df2.set_index(['year', 'month']).plot(figsize=(16, 8))
plt.xlabel('Year and Month', weight='bold')
plt.ylabel('Passengers', weight='bold')
plt.title('Lineplot for passengers with time', weight='bold', size=16)
plt.show()

# %% [markdown]
# ### Plotting line-plot for Regression fit
#
# **Plotting Regression line is simply fitting a straight line (best fit) from all points, minimising the squared error**
#
#
# *Using sns.regplot() for regression line plotting*

# %%
plt.figure(figsize=(12, 6))
df2.passengers.plot(label='Original') # Plotting the original line
sns.regplot(x=df2.index, y=df2.passengers, label='Line is Regression line') # plotting the data points and regression line
plt.xlabel('Index', weight='bold')
plt.ylabel('Passengers', weight='bold')
plt.title('Regression line for passengers data', weight='bold', size=16)
plt.legend()
plt.show()

# %% [markdown]
# ## Bar Charts
#
# Bar Charts is a **graphical representation of categorical data** with rectangular bars. Each bar represents a category and the height of the bar represents the value of the corresponding variable.
#
# **Bar plots are commonly used in both Machine Learning and EDA for the following purposes:**
#
# - **Visualizing distribution of categorical variables**: Bar plots are used to visualize the distribution of categorical variables. In Machine Learning, we often have categorical variables in our dataset that we want to analyze. By using bar plots, we can *visualize the distribution of the variables and identify any patterns or trends*.
#
#
# - **Comparing multiple categories**: Bar plots are useful for comparing multiple categories. In EDA, we may be interested in comparing the performance of different products or services. By plotting the data for each category on a single plot, we can *compare the performance and identify any differences*.
#
#
# - **Visualizing model performance**: Bar plots can be used to visualize the performance of Machine Learning models. By *plotting the model performance metric (such as accuracy or F1 score)* for each model on a single plot, we can compare the performance of the different models and identify the best performing one.
#
#
# - **Visualizing frequency distribution**: Bar plots can be used to visualize the frequency distribution of a variable. For example, in EDA, we may be interested in visualizing the frequency distribution of customer age groups or income brackets. By plotting the data in a bar plot, we can *easily visualize the frequency distribution and identify any patterns or anomalies*.
#
#
# - **Identifying outliers and anomalies**: Bar plots can be used to identify any outliers or anomalies in the data. In EDA, we can use bar plots to visualize the frequency distribution of a variable and **identify any categories that have extremely high or low values**. This can help us identify potential errors in the data or outliers that may need further investigation.
#
# Overall, bar plots are a versatile and useful tool for both Machine Learning and EDA. They can help us visualize the distribution of categorical variables, compare categories, identify outliers and anomalies, and present results in a clear and concise manner.

# %% [markdown]
# ### Mean passengers distribution monthly

# %%
### Plotting mean passengers monthly over whole period

df2[['month', 'passengers']].groupby('month').mean().plot(kind='bar', figsize=(12, 6));

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='month', y='passengers', data=df2[['month', 'passengers']].groupby('month').mean().reset_index())
plt.title('Mean Passengers distributed monthly', weight='bold')
plt.show()

# %% [markdown]
# **Observations:**
# - High passengers during summer, shows vacation travelling more compared to other months
# - Slight increase in passengers mean in winter, due to winter festivals and vacations

# %% [markdown]
# ### Mean passengers distribution yearly

# %%
sns.barplot(x='year', y='passengers', data=df2[['year', 'passengers']].groupby('year').mean().reset_index());

# %% [markdown]
# **Expected the increasing trend**
#
#
# ## Barplot of the FIFA data

# %%
### Plotting the ranking of BRAZIL over years by lineplot and barplot

plt.figure(figsize=(12, 6))
sns.barplot(x='year', y='BRA', data=yearly_mean_ranking[['BRA']].reset_index())
plt.ylabel('Ranking')
plt.xticks(rotation=90)
plt.show()

# %%
### Brazil yearly mean ranking lineplot

sns.lineplot(data=yearly_mean_ranking[['BRA']]);

# %%
### Brazil ranking bar graph plotted grouped by year and month

df[['BRA', 'year', 'month']].groupby(['year', 'month']).mean().astype('int').plot(kind='bar', figsize=(16, 8));

# %%
### Plotting the ranking of Brazil grouped by year and month for all years

dfxx = df[['BRA', 'year', 'month']].groupby(['year', 'month']).mean().astype('int').reset_index()

plt.figure(figsize=(16, 8))
sns.barplot(x='year', y='BRA', hue='month', data=dfxx)
plt.legend(loc='upper left')
plt.show()

# %%
### Plotting line-graph for Brazil ranking

df.set_index('Date')[['BRA']].plot(figsize=(16, 8));

# %% [markdown]
# We can see really good performance till 2011 and then detoriation in Ranking, improving after 2015

# %% [markdown]
# ### Comparing Brazil and Argentina

# %%
### Bar plot using seaborn

plt.figure(figsize=(16, 8))
sns.barplot(x='year', y='ARG', data=yearly_mean_ranking[['ARG']].reset_index())
sns.barplot(x='year', y='BRA', data=yearly_mean_ranking[['BRA']].reset_index())
# Out:
# <AxesSubplot:xlabel='year', ylabel='BRA'>

# %%
### Plot with matplotlib

fig, ax = plt.subplots(1, figsize=(16, 8))
yearly_mean_ranking[['ARG']].plot(kind='bar', ax=ax)
yearly_mean_ranking[['BRA']].plot(kind='bar', ax=ax, color='orange')
plt.xlabel('Year')
plt.ylabel('Ranking')
plt.title('FIFA ranking comparison for Brazil and Argentina', weight='bold', size=16)
plt.show()

# %%
### Parallel Bar graphs

fig, ax = plt.subplots(1, figsize=(16, 8))
yearly_mean_ranking[['ARG', 'BRA']].plot(kind='bar', ax=ax)
plt.xlabel('Year')
plt.ylabel('Ranking')
plt.title('FIFA ranking comparison for Brazil and Argentina', weight='bold', size=16)
plt.show()

# %% [markdown]
# Brazil performance detoriated at the end, when Argentina's overtakes Brazil.

# %% [markdown]
# ## Scatter Plots
#
# A scatter plot is a type of plot that is used to **visualize the relationship between two variables**. Each point in a scatter plot represents a *single observation or data point*, and the position of the point on the plot **represents the values of the two variables**. Scatter plots are useful for *identifying patterns or trends* in the data and for *detecting outliers or anomalies*.
#
# **Uses of Scatter Plots:**
#
# - **Visualizing the relationship between variables**: Scatter plots are commonly used in EDA to visualize the relationship between two variables. For example, we might use a scatter plot to *visualize the relationship between a customer's age and their spending habits*.
#
#
# - **Detecting outliers and anomalies**: Scatter plots can also be used to detect outliers or anomalies in the data. Outliers are observations that are significantly different from the other observations in the dataset, and they can have a significant impact on the results of our analysis.
#
#
# - **Assessing the linearity of the relationship**: Scatter plots can be used to assess the linearity of the relationship between two variables. *If the points in the scatter plot form a clear linear pattern, it suggests that the two variables have a strong linear relationship*. If the points form a non-linear pattern, it suggests that the relationship may be non-linear.
#
#
# - **Visualizing clusters and patterns**: In Machine Learning, scatter plots can be used to visualize clusters and patterns in the data. For example, we might use a scatter plot to *visualize the distribution of different classes or labels in the data*, or to *identify patterns that can be used to create new features for our model*.
#
#
# - **Evaluating model performance**: Scatter plots can be used to evaluate the performance of a machine learning model. For example, we might use a scatter plot to *compare the predicted values of a model to the actual values in the test set*. This can help us identify areas where the model is performing well and areas where it needs improvement.
#
# Overall, scatter plots are a powerful tool for *visualizing the relationship between variables* and *identifying patterns in the data*. By using scatter plots in Machine Learning and EDA, we can **gain insights into our data and develop more accurate and effective models**.

# %%
### Example

plt.figure(figsize=(12, 6))
sns.scatterplot(x=df2.index, y=df2.passengers)
plt.show()

# %%
### Taking another Dataset

iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
### Getting data info

iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Data looks okay, with 3 species, each having 50 data instances.

# %%
### Scatter plotting sepal_length vs sepal_width

plt.figure(figsize=(8, 8))
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris)
plt.title('Sepal length v/s Sepal width SCATTERPLOT', weight='bold', size=14)
plt.show()

# %% [markdown]
# **Plotting Regression line to check Relationship between sepal_width and sepal_length**

# %%
### Scatter plotting sepal_length vs sepal_width

plt.figure(figsize=(8, 8))
sns.regplot(x='sepal_length', y='sepal_width', data=iris)
plt.title('Sepal length v/s Sepal width Regression line', weight='bold', size=14)
plt.show()

# %% [markdown]
# Not much stronger relationship, however a weak negative relationship can be seen.

# %%
### Scatter plotting sepal_length vs sepal_width with species

plt.figure(figsize=(8, 8))
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=iris)
plt.title('Sepal length v/s Sepal width SCATTERPLOT, with Species', weight='bold', size=14)
plt.show()

# %% [markdown]
# **Regression line for each species, using sns.lmplot()**

# %%
### Regression line for sepal_length vs sepal_width with species

sns.lmplot(x='sepal_length', y='sepal_width', hue='species', data=iris)
plt.title('Sepal length v/s Sepal width Regression line, with Species', weight='bold', size=14)
plt.show()

# %% [markdown]
# **Observations:**
# - All 3 species shows **positive correlation**
# - Setosa has the maximum slope, followed by versicolor then virginica

# %%
### Scatter plotting sepal_length vs petal_length

plt.figure(figsize=(8, 8))
sns.scatterplot(x='sepal_length', y='petal_length', hue='species', data=iris)
plt.title('Sepal length v/s Petal length SCATTERPLOT, with Species', weight='bold', size=14)
plt.show()

# %%
### Regression plot for sepal_length vs petal_length

plt.figure(figsize=(8, 8))
sns.lmplot(x='sepal_length', y='petal_length', hue='species', data=iris)
plt.title('Sepal length v/s Petal length SCATTERPLOT, with Species', weight='bold', size=14)
plt.show()

# %% [markdown]
# **Observations:**
# - Positive correlation for all species
# - Very low correlation for setosa sepal vs petal length
# - High and almost equal correlation for versicolor and virginica

# %% [markdown]
# ## Categorical scatter plot using sns.swarmplot()
#
# **Plotting scatter plot for each categories, for a particular variable**

# %%
### Categorical scatter plot for sepal_length variable

plt.figure(figsize=(12, 6))
sns.swarmplot(x='species', y='sepal_length', data=iris)
plt.xlabel('Species', weight='bold')
plt.ylabel('Sepal Length', weight='bold')
plt.title('Categorical Scatter plots', weight='bold', size=14)
plt.show()

# %% [markdown]
# **Observations:**
#
# - Values for virginica is more than that of versicolor which is more than setosa, for the sepal length

# %%
### Categorical scatter plot for petal_length variable

plt.figure(figsize=(12, 6))
sns.swarmplot(x='species', y='petal_length', data=iris)
plt.xlabel('Species', weight='bold')
plt.ylabel('Petal Length', weight='bold')
plt.title('Categorical Scatter plots', weight='bold', size=14)
plt.show()

# %% [markdown]
# - Petal length shows same charachteristics like sepal length, just being less spread

# %% [markdown]
# ## Heatmaps
#
# A heatmap is a graphical representation of data where the **individual values that are contained in a matrix are represented as colors**. It is a powerful visualization tool used in both Machine Learning and EDA for **understanding the correlation between different variables** in a dataset. Heatmaps provide a *quick and easy way to understand patterns and trends* in the data.
#
# **Uses of Heatmaps:**
#
# - **Visualizing Correlations**: Heatmaps are commonly used to visualize the correlation between variables in a dataset. By visualizing the correlations between variables, we can *quickly identify patterns in the data and understand how different variables are related* to one another. This is useful for **identifying which variables are most important for predicting the target variable**.
#
#
# - **Identifying Patterns and Trends**: Heatmaps can be used to **identify patterns in the data that might not be easily visible through other visualization methods**. By analyzing the heatmap, we can **identify clusters of similar values that might indicate patterns or trends in the data**. This can be useful for *identifying outliers, trends, and patterns in the data*.
#
#
# - **Feature Selection**: Heatmaps can also be used for feature selection, which is the process of **selecting the most important features from a dataset**. By analyzing the correlation between different features, we can **identify which features are most important for predicting the target variable**. This can *help in building more accurate and effective models*.
#
#
# - **Data Comparison**: Heatmaps are useful for comparing data across different categories or time periods. By visualizing the data in a heatmap, we can easily **identify which categories or time periods have the highest or lowest values**. This can be useful for identifying trends and patterns in the data.
#
#
# - **Identifying Missing Data**: Heatmaps can be used to identify missing data or null values in a dataset. By visualizing the data in a heatmap, we can *easily identify which cells have missing values or null values*. This can be useful for *data cleaning and preprocessing*.
#
# Overall, heatmaps are a powerful tool for visualizing the relationships between variables in a dataset. By using heatmaps in Machine Learning and EDA, we can gain insights into our data and **develop more accurate and effective models**.

# %%
### Heatmap for correlation between variables in iris dataset

iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
### Heatmap will simply color code the above values, on the basis of their severity

plt.figure(figsize=(10, 8))
sns.heatmap(iris.corr(), annot=True)
plt.show()

# %% [markdown]
# **Observations:**
# - Correlation of 1 with itself
# - sepal_length shows negative correlation with sepal width (also we saw that using regression plot)
# - Sepal length shows high positive correlation with petal length and petal width
# - Sepal width is negatively correlated with all the other features
# - Petal length has high correlation with petal width, same was not in case of sepal length and width

# %%
### Correlation in rankings for all countries

df.iloc[:, 1: 7].astype('int').corr()
# Out:
#           ARG       BRA       ESP       FRA       GER       ITA
# ARG  1.000000 -0.207751 -0.093917 -0.006093 -0.207148 -0.134977
# BRA -0.207751  1.000000 -0.309831  0.534167 -0.342712 -0.017451
# ESP -0.093917 -0.309831  1.000000 -0.324721  0.001515  0.136098
# FRA -0.006093  0.534167 -0.324721  1.000000 -0.436194  0.129993
# GER -0.207148 -0.342712  0.001515 -0.436194  1.000000 -0.011885
# ITA -0.134977 -0.017451  0.136098  0.129993 -0.011885  1.000000

# %%
### Heatmap for ranking correlation

plt.figure(figsize=(10, 8))
sns.heatmap(df.iloc[:, 1:7].corr(), annot=True, fmt='.2f');

# %% [markdown]
# **Observations:**
# - Most countries have negative correlation with other countries. That means ranking of one country do not depends on ranking on other, i.e. independence
# - Brazil has high correlation with France
# - Italy has positive correlation with France and Spain

# %% [markdown]
# ## Pairplot
#
# **Plot the scatter plot for each variable wrt other variable in the data**

# %%
sns.pairplot(iris)
plt.show()

# %% [markdown]
# **Plot of variable with itself here shows histogram**

# %% [markdown]
# ## Pairplot with hue

# %%
sns.pairplot(iris, hue='species')
plt.show()

# %% [markdown]
# ## Plotting Regression plot with pairplot having hue

# %%
sns.pairplot(iris, kind='reg', hue='species')
plt.show()
