# %% [markdown]
# # Handling Missing Value

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from datetime import datetime, timedelta

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
import missingno as msno

# %%
train = pd.read_csv(r'./titanic/train.csv')
test = pd.read_csv(r'./titanic/test.csv')
train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.shape, test.shape
# Out:
# ((891, 12), (418, 11))

# %%
train.info(), test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
train.isna().sum()[train.isna().sum() > 0], test.isna().sum()[test.isna().sum() > 0]
# Out:
# (Age         177
#  Cabin       687
#  Embarked      2
#  dtype: int64,
#  Age       86
#  Fare       1
#  Cabin    327
#  dtype: int64)

# %% [markdown]
# **Missing in train set: (Total: 891)**
# - Age (177 values missing)
# - Cabin (687 values missing)
# - Embarked (2 values missing)
#
# **Missing in test set: (Total 418)**
# - Age (86 values missing)
# - Fare (1 value missing)
# - Cabin (327 value missing)

# %%
trnan = train.isna().sum()[train.isna().sum() > 0].to_frame()
trnan /= len(train)
trnan *= 100
trnan.sort_values([0], ascending=False)
# Out:
#                   0
# Cabin     77.104377
# Age       19.865320
# Embarked   0.224467

# %%
tenan = test.isna().sum()[test.isna().sum() > 0].to_frame()
tenan /= len(test)
tenan *= 100
tenan.sort_values([0], ascending=False)
# Out:
#                0
# Cabin  78.229665
# Age    20.574163
# Fare    0.239234

# %% [markdown]
# **For Cabin, almost 78% of data is missing, so filling up these data based on other 22 data wont make much sense**
#
# ### So, for Cabin, it's better to drop the whole column.
#
# * But first, let's look at the Cabin data

# %%
train.Cabin.value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %% [markdown]
# ## Better to drop Cabin column

# %%
msno.bar(train)
# Out:
# <Axes: >

# %%
msno.matrix(train.sample(100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 msno.matrix(train.sample(100))
#
# File ~\anaconda3\envs\mlEnv\lib\site-packages\missingno\missingno.py:72, in matrix(df, filter, n, p, sort, figsize, width_ratios, color, fontsize, labels, sparkline, inline, freq, ax)
#      70 # Remove extraneous default visual elements.
#      71 ax0.set_aspect('auto')
# ---> 72 ax0.grid(b=False)
#      73 ax0.xaxis.tick_top()
#      74 ax0.xaxis.set_ticks_position('none')
#
# File ~\anaconda3\envs\mlEnv\lib\site-packages\matplotlib\axes\_base.py:3194, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3192 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3193 if axis in ['x', 'both']:
# -> 3194     self.xaxis.grid(visible, which=which, **kwargs)
#    3195 if axis in ['y', 'both']:
#    3196     self.yaxis.grid(visible, which=which, **kwargs)
#
# ...

# %%
msno.bar(test)
# Out:
# <Axes: >

# %%
msno.matrix(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 msno.matrix(test)
#
# File ~\anaconda3\envs\mlEnv\lib\site-packages\missingno\missingno.py:72, in matrix(df, filter, n, p, sort, figsize, width_ratios, color, fontsize, labels, sparkline, inline, freq, ax)
#      70 # Remove extraneous default visual elements.
#      71 ax0.set_aspect('auto')
# ---> 72 ax0.grid(b=False)
#      73 ax0.xaxis.tick_top()
#      74 ax0.xaxis.set_ticks_position('none')
#
# File ~\anaconda3\envs\mlEnv\lib\site-packages\matplotlib\axes\_base.py:3194, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3192 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3193 if axis in ['x', 'both']:
# -> 3194     self.xaxis.grid(visible, which=which, **kwargs)
#    3195 if axis in ['y', 'both']:
#    3196     self.yaxis.grid(visible, which=which, **kwargs)
#
# ...

# %% [markdown]
# Missing at random

# %%
msno.matrix(train.sort_values('Age'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 msno.matrix(train.sort_values('Age'))
#
# File ~\anaconda3\envs\mlEnv\lib\site-packages\missingno\missingno.py:72, in matrix(df, filter, n, p, sort, figsize, width_ratios, color, fontsize, labels, sparkline, inline, freq, ax)
#      70 # Remove extraneous default visual elements.
#      71 ax0.set_aspect('auto')
# ---> 72 ax0.grid(b=False)
#      73 ax0.xaxis.tick_top()
#      74 ax0.xaxis.set_ticks_position('none')
#
# File ~\anaconda3\envs\mlEnv\lib\site-packages\matplotlib\axes\_base.py:3194, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3192 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3193 if axis in ['x', 'both']:
# -> 3194     self.xaxis.grid(visible, which=which, **kwargs)
#    3195 if axis in ['y', 'both']:
# ...

# %%
msno.matrix(test.sort_values('Age'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 msno.matrix(test.sort_values('Age'))
#
# File ~\anaconda3\envs\mlEnv\lib\site-packages\missingno\missingno.py:72, in matrix(df, filter, n, p, sort, figsize, width_ratios, color, fontsize, labels, sparkline, inline, freq, ax)
#      70 # Remove extraneous default visual elements.
#      71 ax0.set_aspect('auto')
# ---> 72 ax0.grid(b=False)
#      73 ax0.xaxis.tick_top()
#      74 ax0.xaxis.set_ticks_position('none')
#
# File ~\anaconda3\envs\mlEnv\lib\site-packages\matplotlib\axes\_base.py:3194, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3192 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3193 if axis in ['x', 'both']:
# -> 3194     self.xaxis.grid(visible, which=which, **kwargs)
#    3195 if axis in ['y', 'both']:
#    3196     self.yaxis.grid(visible, which=which, **kwargs)
# ...

# %% [markdown]
# ### So, there doesn't seem to be any relation of missing Cabin with high age

# %%
msno.heatmap(train)
# Out:
# <Axes: >

# %%
msno.heatmap(test)
# Out:
# <Axes: >

# %% [markdown]
# **So, no particular coorelation between variables**

# %%
msno.dendrogram(train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 msno.dendrogram(train)
#
# File ~\anaconda3\envs\mlEnv\lib\site-packages\missingno\missingno.py:437, in dendrogram(df, method, filter, n, p, orientation, figsize, fontsize, inline, ax)
#     435 # Remove extraneous default visual elements.
#     436 ax0.set_aspect('auto')
# --> 437 ax0.grid(b=False)
#     438 if orientation == 'bottom':
#     439     ax0.xaxis.tick_top()
#
# File ~\anaconda3\envs\mlEnv\lib\site-packages\matplotlib\axes\_base.py:3194, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3192 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3193 if axis in ['x', 'both']:
# -> 3194     self.xaxis.grid(visible, which=which, **kwargs)
#    3195 if axis in ['y', 'both']:
#    3196     self.yaxis.grid(visible, which=which, **kwargs)
#
# ...

# %% [markdown]
# # Missing Value handling techniques:
#
# ### Method-1 (Drop of Row or Column)
# ### Method-2 (Imputation of missing rows)

# %%
# Dropping off Cabin column, as it has 78% missing values

t2 = train.copy()
t2.drop(columns=['Cabin'], inplace=True)
t2.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S

# %%
# Dropping off Row having null values

t2 = train.copy()
print(t2.shape)
t2 = t2.dropna(subset=['Age'])
print(t2.shape)
t2
# Out:
# (891, 12)
# (714, 12)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ## Missing Value Imputation
#
# **There are many ways to deal with Missing values:**
# - Mean, median and mode imputations
# - Backward fill, Forward fill, Linear or Quadratic interpolations
# - Imputation with a constant
# - KNN
# - MICE

# %%
# Mean imputation

t2 = train.copy()
print(t2['Age'].info())
t2['Age'].fillna(t2['Age'].mean(), inplace=True)

print(t2['Age'].mean(), t2['Age'].info(), t2['Age'].mean())

t2
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 714 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB
# 29.69911764705882 None 29.69911764705882
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# ...

# %%
# Median imputation

t2 = train.copy()
print(t2['Age'].info())
t2['Age'].fillna(t2['Age'].median(), inplace=True)

print(t2['Age'].median(), t2['Age'].info())

t2
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 714 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB
# 28.0 None
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# ...

# %%
# Mode imputation

t2 = train.copy()
print(t2['Age'].info())
t2['Age'].fillna(t2['Age'].mode()[0], inplace=True)

print(t2['Age'].mode()[0], t2['Age'].info())

t2
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 714 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB
# None
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    float64
# dtypes: float64(1)
# memory usage: 7.1 KB
# 24.0 None
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# ...

# %% [markdown]
# ## Imputation with sklearn

# %%
from sklearn.impute import SimpleImputer

# %%
# mean

t2 = train.copy()

simean = SimpleImputer(missing_values=np.nan, strategy='mean')
t2['Age'] = simean.fit_transform(t2['Age'].to_numpy().reshape(-1, 1))
t2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# median

t2 = train.copy()

simed = SimpleImputer(missing_values=np.nan, strategy='median')
t2['Age'] = simed.fit_transform(t2['Age'].to_numpy().reshape(-1, 1))
t2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# mode

t2 = train.copy()

simod = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
t2['Age'] = simod.fit_transform(t2['Age'].to_numpy().reshape(-1, 1))
t2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# constant

t2 = train.copy()

siconst = SimpleImputer(missing_values=np.nan, strategy='constant')
t2['Age'] = siconst.fit_transform(t2['Age'].to_numpy().reshape(-1, 1))
print(t2.isna().sum())
t2
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
# mean

t2 = train.copy()
num_cols = t2.select_dtypes(include=np.number).columns.to_list()
print(num_cols)

simean = SimpleImputer(strategy='most_frequent')
t2.loc[:, :] = simean.fit_transform(t2)
print(t2.isna().sum())
t2
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# ...

# %% [markdown]
# # Time series dataset

# %%
data = pd.read_csv('./AQI Data IND/city_day.csv')
data
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
data.isna().sum()[data.isna().sum() > 0]
# Out:
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
dates = pd.date_range(start=pd.to_datetime('2015-01-01'), end=pd.to_datetime('2020-07-01')).to_frame()
dates.rename(columns={0: 'Date'}, inplace=True)
dates
# Out:
#                  Date
# 2015-01-01 2015-01-01
# 2015-01-02 2015-01-02
# 2015-01-03 2015-01-03
# 2015-01-04 2015-01-04
# 2015-01-05 2015-01-05
# ...               ...
# 2020-06-27 2020-06-27
# 2020-06-28 2020-06-28
# 2020-06-29 2020-06-29
# 2020-06-30 2020-06-30
# 2020-07-01 2020-07-01
#
# [2009 rows x 1 columns]

# %%
data.City.unique()
# Out:
# array(['Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru',
#        'Bhopal', 'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore',
#        'Delhi', 'Ernakulam', 'Gurugram', 'Guwahati', 'Hyderabad',
#        'Jaipur', 'Jorapokhar', 'Kochi', 'Kolkata', 'Lucknow', 'Mumbai',
#        'Patna', 'Shillong', 'Talcher', 'Thiruvananthapuram',
#        'Visakhapatnam'], dtype=object)

# %%
data['Date'] = pd.to_datetime(data['Date'])

print(data.shape)
for city in data.City.unique():
    print(city)
    df = data.loc[data.City == city]
    df = pd.merge(df, dates, on='Date', how='outer')
    df['City'].fillna(method='ffill', inplace=True)
    df['City'].fillna(method='bfill', inplace=True)
    print(df['City'].isna().sum())

    data = pd.merge(data, df[['City', 'Date']], on=['City', 'Date'], how='outer')
    
print(data.shape)
data
# Out:
# (29531, 16)
# Ahmedabad
# 0
# Aizawl
# 0
# Amaravati
# 0
# Amritsar
# 0
# Bengaluru
# 0
# Bhopal
# 0
# Brajrajnagar
# 0
# Chandigarh
# 0
# Chennai
# 0
# Coimbatore
# 0
# Delhi
# 0
# Ernakulam
# 0
# Gurugram
# 0
# Guwahati
# 0
# Hyderabad
# 0
# Jaipur
# 0
# Jorapokhar
# 0
# Kochi
# 0
# Kolkata
# 0
# Lucknow
# 0
# Mumbai
# 0
# Patna
# 0
# Shillong
# 0
# Talcher
# 0
# Thiruvananthapuram
# 0
# Visakhapatnam
# 0
# (52234, 16)
#                 City       Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO  \
# 0          Ahmedabad 2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92
# 1          Ahmedabad 2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97
# 2          Ahmedabad 2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40
# 3          Ahmedabad 2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70
# 4          Ahmedabad 2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10
# ...              ...        ...    ...   ...    ...    ...    ...  ...    ...
# ...

# %%
data.loc[data.City.isna() == 1]
# Out:
# Empty DataFrame
# Columns: [City, Date, PM2.5, PM10, NO, NO2, NOx, NH3, CO, SO2, O3, Benzene, Toluene, Xylene, AQI, AQI_Bucket]
# Index: []

# %%
data.isna().sum()[data.isna().sum() > 0].to_frame().sort_values(0, ascending=False)
# Out:
#                 0
# Xylene      40812
# PM10        33843
# NH3         33031
# Toluene     30744
# Benzene     28326
# AQI         27384
# AQI_Bucket  27384
# PM2.5       27301
# NOx         26888
# O3          26725
# SO2         26557
# NO2         26288
# NO          26285
# CO          24762

# %%
data['CO'].fillna('ffill', inplace=True)
data['CO'].isna().sum()
# Out:
# 0

# %%
data['Xylene'].fillna('bfill', inplace=True)
data['Xylene'].isna().sum()
# Out:
# 0

# %%
data['NO2'].interpolate(method='linear', inplace=True)
data['NO2'].isna().sum()
# Out:
# 0

# %%
data['SO2'].interpolate(method='quadratic', inplace=True)
data['SO2'].isna().sum()
# Out:
# 22703

# %%
data['SO2'].interpolate(method='cubic', inplace=True)
data['SO2'].isna().sum()
# Out:
# 22703

# %%
data['SO2'].interpolate(method='nearest', inplace=True)
data['SO2'].isna().sum()
# Out:
# 22703

# %%
data['SO2'].interpolate(method='linear', inplace=True)
data['SO2'].isna().sum()
# Out:
# 0

# %% [markdown]
# # Multivariate Imputation (KNN, MICE (IterativeImputer) )

# %%
from sklearn.experimental import enable_iterative_imputer # to be used with iterative imputer
from sklearn.impute import IterativeImputer, KNNImputer

# %%
t2 = train.copy()

knn = KNNImputer(n_neighbors=5, weights='uniform')
t2['Age'] = knn.fit_transform(t2[['Age']])
print(t2.isna().sum()[t2.isna().sum() > 0])

t2
# Out:
# Cabin       687
# Embarked      2
# dtype: int64
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ...

# %%
t2 = train.copy()

iterimp = IterativeImputer()
t2['Age'] = iterimp.fit_transform(t2[['Age']])
print(t2.isna().sum()[t2.isna().sum() > 0])

t2
# Out:
# Cabin       687
# Embarked      2
# dtype: int64
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ...
